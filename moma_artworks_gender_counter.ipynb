# %%
# import pandas and rename as pd
import pandas as pd

# importing other libraries
import nltk
import numpy
from collections import Counter

# %%
# set the path to our file
path = 'moma_artworks.csv'
# convert our csv file to a pandas DataFrame
artworks = pd.read_csv(path)

# %%
# print out our dataset
artworks
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 140843            Page from Sketchbook #24, New York City
# 140844            Page from Sketchbook #24, New York City
# 140845            Page from Sketchbook #24, New York City
# 140846       Front cover of Sketchbook #24, New York City
# 140847  Front cover (verso) of Sketchbook #24, New Yor...
#
#                           Artist ConstituentID  \
# 0                    Otto Wagner          6210
# 1       Christian de Portzamparc          7470
# 2                     Emil Hoppe          7605
# 3                Bernard Tschumi          7056
# ...

# %%
# how many missing values we have in our dataset
# ?? artworks.isnull().any().sum()
# returns 25

# %%
# (just for fun)
# finding which of Rothko's works are within the collection
artworks.loc[artworks.Artist == 'Mark Rothko']
# Out:
#                                               Title       Artist  \
# 33123                                      Untitled  Mark Rothko
# 33195                                  Archaic Idol  Mark Rothko
# 34862                                      Untitled  Mark Rothko
# 34864                                      Untitled  Mark Rothko
# 34867                                      Untitled  Mark Rothko
# 34870                                      Untitled  Mark Rothko
# 34874                                      Untitled  Mark Rothko
# 62734                                      Untitled  Mark Rothko
# 73166                No. 16 (Red, Brown, and Black)  Mark Rothko
# 73251                                        No. 10  Mark Rothko
# 74020  No. 37/No. 19 (Slate Blue and Brown on Plum)  Mark Rothko
# 74034                                      Untitled  Mark Rothko
# 74087                                  No. 3/No. 13  Mark Rothko
# ...

# %%
# checking what data type our columns are in
# it is a string... we want a list
type(artworks.Artist)
# Out:
# pandas.core.series.Series

# %%
# converting Artist from a string to a list
artist = (artworks.Artist).tolist()
print(artist)
# Out:
# ['Otto Wagner', 'Christian de Portzamparc', 'Emil Hoppe', 'Bernard Tschumi', 'Emil Hoppe', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Louis I. Kahn', 'Bernard Tschumi', 'Marcel Kammerer', 'Bernard Tschumi', 'Otto Schönthal', 'Bernard Tschumi', 'Otto Schönthal', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi', 'Bernard Tschumi',
# ...

# %%
# we can check this has become a list by repeating type
type(artist)
# Out:
# list

# %%
# lets do the same for gender
# we can use dot notation, because we are using the pandas library and no space in the column name
sex = (artworks.Gender).tolist()

# %%
# print out the gender of the artist behind our first artwork
# no surprises there... it's a male! 
sex[0]
# Out:
# '(Male)'

# %%
# see how many individual genders of artists there are within moma's collection
len(artworks.Gender.unique())
# Out:
# 413

# %%
# 413 sounds like a lot of different genders... lets print them out to see what is going on
artworks.Gender.unique()
# Out:
# array(['(Male)', '(Male) (Male)', '(Male) (Female)',
#        '(Male) (Male) (Male)', '() (Female) (Male)', '(Female)',
#        '(Male) (Female) (Male) (Female)', '() (Male) (Male)',
#        '() (Male) (Male) (Female)', '(Male) (Male) (Female) (Female)',
#        '(Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Female) (Female) (Male)',
#        '(Male) () (Male) (Female) (Male) (Male) (Male) (Male) (Female)',
#        '() (Male)', '()', '() (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) () ()', '() (Male) (Male) (Male) (Male) (Male)',
#        '(Female) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Female) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male)',
#        '(Male) (Female) (Male)', '(Male) (Male) () ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male)',
# ...

# %%
# ... as suspected, we have encountered a lot of formatting issues within the data
# python recognises 'male' and ' male' and 'male male' as seperate values, in this case creating more genders than exist
# this renders our dataset ineffective for classifying artworks based on gender as our data is inaccurate

# gathering, sorting, and preparing data is the most important step in the data analysis process
# bad data can have cumulative negative effects downstream if it is not corrected
# data prep/wrangling, involves the manipulation of data so that it is most suitable for machine interpretation
# critical step for accurate analysis

# %%
# it seems that some of the artworks have multiple contributors
# just as each of their names are credited, their individual genders are too
# python observes this as a new gender in itself and not a counter to the other genders

three_male_artists = artworks[[ x for x in artworks['Gender'] == '() (Male) (Male) (Male)']]

# %%
# we are turning these values in to a list using the split command so that we can include them within our counter of individual male artists

three_male_artists.iloc[0].Gender.split()
# Out:
# ['()', '(Male)', '(Male)', '(Male)']

# %%
# finding works by non-binary artists within the collection
artworks.loc[artworks.Gender == '(Non-Binary)']
# Out:
#                             Title         Artist ConstituentID  \
# 93594              The Judy Spots  Sadie Benning         34902
# 93595                     Jollies  Sadie Benning         34902
# 93598   If Every Girl Had a Diary  Sadie Benning         34902
# 93599               Living Inside  Sadie Benning         34902
# 93604           Flat is Beautiful  Sadie Benning         34902
# 93605                  A New Year  Sadie Benning         34902
# 93607            Me and Rubyfruit  Sadie Benning         34902
# 93625                 German Song  Sadie Benning         34902
# 120252                Julie's Rug  Sadie Benning         34902
# 128883                 Shared Eye  Sadie Benning         34902
# 132075                Weed Killer  Patrick Staff         74347
#
#                     ArtistBio Nationality BeginDate EndDate        Gender  \
# 93594   (American, born 1973)  (American)    (1973)     (0)  (Non-Binary)
# ...

# %%
# setting our counters at 0
female_counter = 0
male_counter = 0
non_binary_counter = 0

# %%
sex_of_artist = [ x for x in artworks['Gender']]

# %%
# print the 1st value of 
sex_of_artist[0]
# Out:
# '(Male)'

# %%
type(sex_of_artist)
# Out:
# list

# %%
# turning all the artist gender values into a list

for x in sex_of_artist:
    if not isinstance(x, str): 
        artist_gender_list+=1
        continue
    print(x)
    x.split()
    
    # effectively this is what we are doing: 
    # test ='() (Male) (Male)'
    # new_list = test.split()
    # print(new_list)
    # like we did before with three_male_artists
    
# assigning all the values(genders) from our newly-formed list x.split() into their own gendered list
# i.e. list of male artists from artist_gender_list is represented within male_counter as an int
# if male then increment male counter +=1 etc
# elif is an abbreviation of else if function - a neater way to code rather than writing continue under each line
    
    artist_gender_list = x.split()
    for y in artist_gender_list:
        if y =='(Male)':
            male_counter+=1
        elif y =='(Female)':
            female_counter+=1
        elif y =='(Non-Binary)':
            non_binary_counter+=1
        elif y =='(Non-binary)':
            non_binary_counter+=1
            
            # !! rename 'Non-binary' value as 'Non-Binary' by capitalise function to avoid having to create another for loop
            
    # instead of the missing instances of gender data with blank spaces, we could also make use of premade classifier features
    # python has various add ons which attempt to classify names to a gender binary
    # see genderPredictor.py, gender-guesser.py or gender-from-name.py
# Out:
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male) (Male)
# (Male) (Female)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male) (Male) (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# (Male)
# ...

# %%
# we can see that the number of male artists has risen since we have included our '(Male Male Male)' instances as increments
# via split list so each has become '(Male)''(Male)''(Male)'
# !!! why is this not displaying full dataset?! even if i let it load fully it comes back with a random number of values
# same data patterns in ratio but inconsistent numbers
male_counter
# Out:
# 1378

# %%
# no, this is not an error...
# there really are 10x more artworks by male artists in moma's collection than there are by female artists
print(male_counter)
print(female_counter)
print(non_binary_counter)
# Out:
# 1378
# 178
# 0

# %%
# total of recorded artist genders within my dataset
(male_counter)+(female_counter)+(non_binary_counter)
# Out:
# 1556

# %%
# if we have done this correctly, the number of unique genders should change to 3
# len(artworks.sex_of_artist.unique())
# !!!!! check your syntax on this 
print(len(sex.unique()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       1 # if we have done this correctly, the number of unique genders should change to 3
#       2 # len(artworks.sex_of_artist.unique())
#       3 # !!!!! check your syntax on this
# ----> 4 print(len(sex.unique()))
#
# AttributeError: 'list' object has no attribute 'unique'

# %%
# we can confirm this by counter as well as check how many of each gender is represented within the dataset
Counter(sex)
# Out:
# Counter({'(Male)': 105646,
#          '(Male) (Male)': 1644,
#          '(Male) (Female)': 833,
#          '(Male) (Male) (Male)': 1067,
#          '() (Female) (Male)': 24,
#          '(Female)': 18828,
#          '(Male) (Female) (Male) (Female)': 4,
#          '() (Male) (Male)': 69,
#          '() (Male) (Male) (Female)': 10,
#          '(Male) (Male) (Female) (Female)': 25,
#          '(Male) (Male) (Male) (Male) (Male)': 13,
#          '(Male) (Female) (Female) (Male)': 1,
#          '(Male) () (Male) (Female) (Male) (Male) (Male) (Male) (Female)': 1,
#          '() (Male)': 525,
#          '()': 7360,
#          '() (Male) (Male) (Male) (Male) (Male) (Male)': 12,
#          '(Male) () ()': 41,
#          '() (Male) (Male) (Male) (Male) (Male)': 26,
#          '(Female) (Male)': 480,
#          '() (Male) (Male) (Male) (Male) (Male) (Male) (Male)': 3,
#          '() (Male) (Male) (Male) (Female) (Male)': 2,
# ...
